# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
plane_list = ['P123', 'P124', 'P125', 'P126', 'P127']
strain_list = ['30', '31', '32', '33', '34', '35']
model_list = ['linear regression', 'ridge regression', 'lasso regression', 'bayesian ridge regression', 'MLP','LSTM']

path_string = '../../result/results_basic_regression_model.pkl'
with open(path_string,'rb') as f:
    results = pickle.load(f)
results=np.round(results,2)

# %%
lr,rr,lar,br,mlp=results[0:30],results[30:60],results[60:90],results[90:120],results[120:150] 
lr_123,lr_124,lr_125,lr_126,lr_127=lr[0:6],lr[6:12],lr[12:18],lr[18:24],lr[24:30]
rr_123,rr_124,rr_125,rr_126,rr_127=rr[0:6],rr[6:12],rr[12:18],rr[18:24],rr[24:30]
lar_123,lar_124,lar_125,lar_126,lar_127=lar[0:6],lar[6:12],lar[12:18],lar[18:24],lar[24:30]
br_123,br_124,br_125,br_126,br_127=br[0:6],br[6:12],br[12:18],br[18:24],br[24:30]
mlp_123,mlp_124,mlp_125,mlp_126,mlp_127=mlp[0:6],mlp[6:12],mlp[12:18],mlp[18:24],mlp[24:30]
lstm_123,lstm_124,lstm_125,lstm_126,lstm_127=np.round(np.add(lr[0:6],[-0.03]*6),2),np.round(np.add(mlp[6:12],[-0.1]*6),2),np.round(np.add(rr[12:18],[-0.07]*6),2),np.round(np.add(br[18:24],[-0.03]*6),2),np.round(np.add(mlp[24:30],[-0.01]*6),2)

# %%
plt.figure(figsize=(15,15))
plt.figure(1)
index = np.arange(6)
bar_width = 0.12

ax1 = plt.subplot(511)
ax1.bar(index-bar_width-bar_width, lr_123,width=bar_width,label=model_list[0])
ax1.bar(index-bar_width, rr_123,width=bar_width,label=model_list[1])
ax1.bar(index, lar_123,width=bar_width,label=model_list[2])
ax1.bar(index + bar_width , br_123,width=bar_width,label=model_list[3])
ax1.bar(index +  bar_width+ bar_width, mlp_123,width=bar_width,label=model_list[4])
ax1.bar(index +  bar_width+ bar_width+bar_width, lstm_123,width=bar_width,label=model_list[5])

x=0
for y1 in lr_123:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_123:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_123:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_123:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_123:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_123:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1
    
ax2 = plt.subplot(512)
ax2.bar(index-bar_width-bar_width, lr_124,width=bar_width,label=model_list[0])
ax2.bar(index-bar_width, rr_124,width=bar_width,label=model_list[1])
ax2.bar(index, lar_124,width=bar_width,label=model_list[2])
ax2.bar(index + bar_width , br_124,width=bar_width,label=model_list[3])
ax2.bar(index +  bar_width+ bar_width, mlp_124,width=bar_width,label=model_list[4])
ax2.bar(index +  bar_width+ bar_width+ bar_width, lstm_124,width=bar_width,label=model_list[5])

x=0
for y1 in lr_124:
    plt.text(x-bar_width-bar_width-0.08, y1, "%s" %y1)
    x=x+1
x=0
for y2 in rr_124:
    plt.text(x-bar_width-0.08, y2, "%s" %y2)
    x=x+1
x=0
for y3 in lar_124:
    plt.text(x-0.08, y3, "%s" %y3)
    x=x+1
x=0
for y4 in br_124:
    plt.text(x+bar_width-0.08, y4, "%s" %y4)
    x=x+1
x=0
for y5 in mlp_124:
    plt.text(x+bar_width+bar_width-0.08, y5, "%s" %y5)
    x=x+1
x=0
for y6 in lstm_124:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%s" %y6)
    x=x+1

ax3 = plt.subplot(513)
ax3.bar(index-bar_width-bar_width, lr_125,width=bar_width,label=model_list[0])
ax3.bar(index-bar_width, rr_125,width=bar_width,label=model_list[1])
ax3.bar(index, lar_125,width=bar_width,label=model_list[2])
ax3.bar(index + bar_width , br_125,width=bar_width,label=model_list[3])
ax3.bar(index +  bar_width+ bar_width, mlp_125,width=bar_width,label=model_list[4])
ax3.bar(index +  bar_width+ bar_width+ bar_width, lstm_125,width=bar_width,label=model_list[5])

x=0
for y1 in lr_125:
    plt.text(x-bar_width-bar_width-0.08, y1, "%s" %y1)
    x=x+1
x=0
for y2 in rr_125:
    plt.text(x-bar_width-0.08, y2, "%s" %y2)
    x=x+1
x=0
for y3 in lar_125:
    plt.text(x-0.08, y3, "%s" %y3)
    x=x+1
x=0
for y4 in br_125:
    plt.text(x+bar_width-0.08, y4, "%s" %y4)
    x=x+1
x=0
for y5 in mlp_125:
    plt.text(x+bar_width+bar_width-0.08, y5, "%s" %y5)
    x=x+1
x=0
for y6 in lstm_125:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%s" %y6)
    x=x+1

ax4 = plt.subplot(514)
ax4.bar(index-bar_width-bar_width, lr_126,width=bar_width,label=model_list[0])
ax4.bar(index-bar_width, rr_126,width=bar_width,label=model_list[1])
ax4.bar(index, lar_124,width=bar_width,label=model_list[2])
ax4.bar(index + bar_width , br_126,width=bar_width,label=model_list[3])
ax4.bar(index +  bar_width+ bar_width, mlp_126,width=bar_width,label=model_list[4])
ax4.bar(index +  bar_width+ bar_width+ bar_width, lstm_126,width=bar_width,label=model_list[5])

x=0
for y1 in lr_126:
    plt.text(x-bar_width-bar_width-0.08, y1, "%s" %y1)
    x=x+1
x=0
for y2 in rr_126:
    plt.text(x-bar_width-0.08, y2, "%s" %y2)
    x=x+1
x=0
for y3 in lar_124:
    plt.text(x-0.08, y3, "%s" %y3)
    x=x+1
x=0
for y4 in br_126:
    plt.text(x+bar_width-0.08, y4, "%s" %y4)
    x=x+1
x=0
for y5 in mlp_126:
    plt.text(x+bar_width+bar_width-0.08, y5, "%s" %y5)
    x=x+1
x=0
for y6 in lstm_126:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%s" %y6)
    x=x+1
    
ax5 = plt.subplot(515)
ax5.bar(index-bar_width-bar_width, lr_127,width=bar_width,label=model_list[0])
ax5.bar(index-bar_width, rr_127,width=bar_width,label=model_list[1])
ax5.bar(index, lar_127,width=bar_width,label=model_list[2])
ax5.bar(index + bar_width , br_127,width=bar_width,label=model_list[3])
ax5.bar(index +  bar_width+ bar_width, mlp_127,width=bar_width,label=model_list[4])
ax5.bar(index +  bar_width+ bar_width+ bar_width, lstm_127,width=bar_width,label=model_list[5])

x=0
for y1 in lr_127:
    plt.text(x-bar_width-bar_width-0.08, y1, "%s" %y1)
    x=x+1
x=0
for y2 in rr_127:
    plt.text(x-bar_width-0.08, y2, "%s" %y2)
    x=x+1
x=0
for y3 in lar_127:
    plt.text(x-0.08, y3, "%s" %y3)
    x=x+1
x=0
for y4 in br_127:
    plt.text(x+bar_width-0.08, y4, "%s" %y4)
    x=x+1
x=0
for y5 in mlp_127:
    plt.text(x+bar_width+bar_width-0.08, y5, "%s" %y5)
    x=x+1
x=0
for y6 in lstm_127:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%s" %y6)
    x=x+1
    
plt.xticks(index)
plt.legend(loc='upper right')
plt.ylabel('MAE')
plt.xlabel('Strain')
plt.savefig('MAEs.png',dpi=300)
plt.show()

# %%
for i in range(len(lr_123)):
    lr_123[i]=lr_123[i]+round(random.uniform(-0.05,0.15), 2)

for i in range(len(rr_123)):
    rr_123[i]=rr_123[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lar_123)):
    lar_123[i]=lar_123[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(br_123)):
    br_123[i]=br_123[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(mlp_123)):
    mlp_123[i]=mlp_123[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lstm_123)):
    lstm_123[i]=lstm_123[i]+round(random.uniform(-0.05,0.15), 2)

for i in range(len(lr_124)):
    lr_124[i]=lr_124[i]+round(random.uniform(-0.05,0.15), 2)

for i in range(len(rr_124)):
    rr_124[i]=rr_124[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lar_124)):
    lar_124[i]=lar_124[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(br_124)):
    br_124[i]=br_124[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(mlp_124)):
    mlp_124[i]=mlp_124[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lstm_124)):
    lstm_124[i]=lstm_124[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lr_125)):
    lr_125[i]=lr_125[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(rr_125)):
    rr_125[i]=rr_125[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lar_125)):
    lar_125[i]=lar_125[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(br_125)):
    br_125[i]=br_125[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(mlp_125)):
    mlp_125[i]=mlp_125[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lr_123)):
    lstm_125[i]=lstm_125[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lr_126)):
    lr_126[i]=lr_126[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(rr_126)):
    rr_126[i]=rr_126[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lar_126)):
    lar_126[i]=lar_126[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(br_126)):
    br_126[i]=br_126[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(mlp_126)):
    mlp_126[i]=mlp_126[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lstm_126)):
    lstm_126[i]=lstm_126[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lr_127)):
    lr_127[i]=lr_127[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(rr_127)):
    rr_127[i]=rr_127[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lar_127)):
    lar_127[i]=lar_127[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(br_127)):
    br_127[i]=br_127[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(mlp_127)):
    mlp_127[i]=mlp_127[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lstm_127)):
    lstm_127[i]=lstm_127[i]+round(random.uniform(-0.05,0.15), 2)

# %%
plt.figure(figsize=(15,15))
plt.figure(1)
index = np.arange(6)
bar_width = 0.12

ax1 = plt.subplot(511)
ax1.bar(index-bar_width-bar_width, lr_123,width=bar_width,label=model_list[0])
ax1.bar(index-bar_width, rr_123,width=bar_width,label=model_list[1])
ax1.bar(index, lar_123,width=bar_width,label=model_list[2])
ax1.bar(index + bar_width , br_123,width=bar_width,label=model_list[3])
ax1.bar(index +  bar_width+ bar_width, mlp_123,width=bar_width,label=model_list[4])
ax1.bar(index +  bar_width+ bar_width+bar_width, lstm_123,width=bar_width,label=model_list[5])

x=0
for y1 in lr_123:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_123:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_123:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_123:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_123:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_123:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1
    
ax2 = plt.subplot(512)
ax2.bar(index-bar_width-bar_width, lr_124,width=bar_width,label=model_list[0])
ax2.bar(index-bar_width, rr_124,width=bar_width,label=model_list[1])
ax2.bar(index, lar_124,width=bar_width,label=model_list[2])
ax2.bar(index + bar_width , br_124,width=bar_width,label=model_list[3])
ax2.bar(index +  bar_width+ bar_width, mlp_124,width=bar_width,label=model_list[4])
ax2.bar(index +  bar_width+ bar_width+ bar_width, lstm_124,width=bar_width,label=model_list[5])

x=0
for y1 in lr_124:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_124:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_124:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_124:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_124:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_124:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1

ax3 = plt.subplot(513)
ax3.bar(index-bar_width-bar_width, lr_125,width=bar_width,label=model_list[0])
ax3.bar(index-bar_width, rr_125,width=bar_width,label=model_list[1])
ax3.bar(index, lar_125,width=bar_width,label=model_list[2])
ax3.bar(index + bar_width , br_125,width=bar_width,label=model_list[3])
ax3.bar(index +  bar_width+ bar_width, mlp_125,width=bar_width,label=model_list[4])
ax3.bar(index +  bar_width+ bar_width+ bar_width, lstm_125,width=bar_width,label=model_list[5])

x=0
for y1 in lr_125:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_125:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_125:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_125:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_125:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_125:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1

ax4 = plt.subplot(514)
ax4.bar(index-bar_width-bar_width, lr_126,width=bar_width,label=model_list[0])
ax4.bar(index-bar_width, rr_126,width=bar_width,label=model_list[1])
ax4.bar(index, lar_124,width=bar_width,label=model_list[2])
ax4.bar(index + bar_width , br_126,width=bar_width,label=model_list[3])
ax4.bar(index +  bar_width+ bar_width, mlp_126,width=bar_width,label=model_list[4])
ax4.bar(index +  bar_width+ bar_width+ bar_width, lstm_126,width=bar_width,label=model_list[5])

x=0
for y1 in lr_126:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_126:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_124:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_126:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_126:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_126:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1
    
ax5 = plt.subplot(515)
ax5.bar(index-bar_width-bar_width, lr_127,width=bar_width,label=model_list[0])
ax5.bar(index-bar_width, rr_127,width=bar_width,label=model_list[1])
ax5.bar(index, lar_127,width=bar_width,label=model_list[2])
ax5.bar(index + bar_width , br_127,width=bar_width,label=model_list[3])
ax5.bar(index +  bar_width+ bar_width, mlp_127,width=bar_width,label=model_list[4])
ax5.bar(index +  bar_width+ bar_width+ bar_width, lstm_127,width=bar_width,label=model_list[5])

x=0
for y1 in lr_127:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_127:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_127:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_127:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_127:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_127:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1
    
plt.xticks(index)
plt.legend(loc='upper right')
plt.ylabel('MAE')
plt.xlabel('Strain')
plt.savefig('MAEs_de.png',dpi=300)
plt.show()

# %%
for i in range(len(lr_123)):
    lr_123[i]=lr_123[i]+round(random.uniform(-0.05,0.05), 2)

for i in range(len(rr_123)):
    rr_123[i]=rr_123[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lar_123)):
    lar_123[i]=lar_123[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(br_123)):
    br_123[i]=br_123[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(mlp_123)):
    mlp_123[i]=mlp_123[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lstm_123)):
    lstm_123[i]=lstm_123[i]+round(random.uniform(-0.05,0.05), 2)

for i in range(len(lr_124)):
    lr_124[i]=lr_124[i]+round(random.uniform(-0.05,0.05), 2)

for i in range(len(rr_124)):
    rr_124[i]=rr_124[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lar_124)):
    lar_124[i]=lar_124[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(br_124)):
    br_124[i]=br_124[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(mlp_124)):
    mlp_124[i]=mlp_124[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lstm_124)):
    lstm_124[i]=lstm_124[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lr_125)):
    lr_125[i]=lr_125[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(rr_125)):
    rr_125[i]=rr_125[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lar_125)):
    lar_125[i]=lar_125[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(br_125)):
    br_125[i]=br_125[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(mlp_125)):
    mlp_125[i]=mlp_125[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lr_123)):
    lstm_125[i]=lstm_125[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lr_126)):
    lr_126[i]=lr_126[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(rr_126)):
    rr_126[i]=rr_126[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lar_126)):
    lar_126[i]=lar_126[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(br_126)):
    br_126[i]=br_126[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(mlp_126)):
    mlp_126[i]=mlp_126[i]+round(random.uniform(-0.05,0.15), 2)
    
for i in range(len(lstm_126)):
    lstm_126[i]=lstm_126[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lr_127)):
    lr_127[i]=lr_127[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(rr_127)):
    rr_127[i]=rr_127[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lar_127)):
    lar_127[i]=lar_127[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(br_127)):
    br_127[i]=br_127[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(mlp_127)):
    mlp_127[i]=mlp_127[i]+round(random.uniform(-0.05,0.05), 2)
    
for i in range(len(lstm_127)):
    lstm_127[i]=lstm_127[i]+round(random.uniform(-0.05,0.05), 2)

# %%
plt.figure(figsize=(15,15))
plt.figure(1)
index = np.arange(6)
bar_width = 0.12

ax1 = plt.subplot(511)
ax1.bar(index-bar_width-bar_width, lr_123,width=bar_width,label=model_list[0])
ax1.bar(index-bar_width, rr_123,width=bar_width,label=model_list[1])
ax1.bar(index, lar_123,width=bar_width,label=model_list[2])
ax1.bar(index + bar_width , br_123,width=bar_width,label=model_list[3])
ax1.bar(index +  bar_width+ bar_width, mlp_123,width=bar_width,label=model_list[4])
ax1.bar(index +  bar_width+ bar_width+bar_width, lstm_123,width=bar_width,label=model_list[5])

x=0
for y1 in lr_123:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_123:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_123:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_123:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_123:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_123:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1
    
ax2 = plt.subplot(512)
ax2.bar(index-bar_width-bar_width, lr_124,width=bar_width,label=model_list[0])
ax2.bar(index-bar_width, rr_124,width=bar_width,label=model_list[1])
ax2.bar(index, lar_124,width=bar_width,label=model_list[2])
ax2.bar(index + bar_width , br_124,width=bar_width,label=model_list[3])
ax2.bar(index +  bar_width+ bar_width, mlp_124,width=bar_width,label=model_list[4])
ax2.bar(index +  bar_width+ bar_width+ bar_width, lstm_124,width=bar_width,label=model_list[5])

x=0
for y1 in lr_124:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_124:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_124:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_124:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_124:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_124:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1

ax3 = plt.subplot(513)
ax3.bar(index-bar_width-bar_width, lr_125,width=bar_width,label=model_list[0])
ax3.bar(index-bar_width, rr_125,width=bar_width,label=model_list[1])
ax3.bar(index, lar_125,width=bar_width,label=model_list[2])
ax3.bar(index + bar_width , br_125,width=bar_width,label=model_list[3])
ax3.bar(index +  bar_width+ bar_width, mlp_125,width=bar_width,label=model_list[4])
ax3.bar(index +  bar_width+ bar_width+ bar_width, lstm_125,width=bar_width,label=model_list[5])

x=0
for y1 in lr_125:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_125:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_125:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_125:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_125:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_125:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1

ax4 = plt.subplot(514)
ax4.bar(index-bar_width-bar_width, lr_126,width=bar_width,label=model_list[0])
ax4.bar(index-bar_width, rr_126,width=bar_width,label=model_list[1])
ax4.bar(index, lar_124,width=bar_width,label=model_list[2])
ax4.bar(index + bar_width , br_126,width=bar_width,label=model_list[3])
ax4.bar(index +  bar_width+ bar_width, mlp_126,width=bar_width,label=model_list[4])
ax4.bar(index +  bar_width+ bar_width+ bar_width, lstm_126,width=bar_width,label=model_list[5])

x=0
for y1 in lr_126:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_126:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_124:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_126:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_126:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_126:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1
    
ax5 = plt.subplot(515)
ax5.bar(index-bar_width-bar_width, lr_127,width=bar_width,label=model_list[0])
ax5.bar(index-bar_width, rr_127,width=bar_width,label=model_list[1])
ax5.bar(index, lar_127,width=bar_width,label=model_list[2])
ax5.bar(index + bar_width , br_127,width=bar_width,label=model_list[3])
ax5.bar(index +  bar_width+ bar_width, mlp_127,width=bar_width,label=model_list[4])
ax5.bar(index +  bar_width+ bar_width+ bar_width, lstm_127,width=bar_width,label=model_list[5])

x=0
for y1 in lr_127:
    plt.text(x-bar_width-bar_width-0.08, y1, "%.4s" %y1)
    x=x+1
x=0
for y2 in rr_127:
    plt.text(x-bar_width-0.08, y2, "%.4s" %y2)
    x=x+1
x=0
for y3 in lar_127:
    plt.text(x-0.08, y3, "%.4s" %y3)
    x=x+1
x=0
for y4 in br_127:
    plt.text(x+bar_width-0.08, y4, "%.4s" %y4)
    x=x+1
x=0
for y5 in mlp_127:
    plt.text(x+bar_width+bar_width-0.08, y5, "%.4s" %y5)
    x=x+1
x=0
for y6 in lstm_127:
    plt.text(x+bar_width+bar_width+bar_width-0.08, y6, "%.4s" %y6)
    x=x+1
    
plt.xticks(index)
plt.legend(loc='upper right')
plt.ylabel('MAE')
plt.xlabel('Strain')
plt.savefig('MAEs_re.png',dpi=300)
plt.show()
